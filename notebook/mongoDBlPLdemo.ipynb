# %%
import os

# %%
import pandas as pd
import pymongo

# %%
data = pd.read_csv("data.csv")

# %%
data.sample(5)
# Out:
#             id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 140191  140192  Female   26                1         46.0                   0
# 365420  365421    Male   32                1         28.0                   0
# 349736  349737    Male   50                1         28.0                   0
# 16798    16799    Male   58                1          8.0                   0
# 357749  357750    Male   26                1         28.0                   1
#
#        Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  \
# 140191    < 1 Year             No          2630.0                   1.0
# 365420   > 2 Years            Yes         65859.0                 122.0
# 349736    1-2 Year            Yes         46538.0                  26.0
# 16798     1-2 Year            Yes         25768.0                  26.0
# 357749    < 1 Year             No         34922.0                 152.0
#
#         Vintage  Response
# 140191       64         0
# 365420      135         0
# 349736      138         0
# 16798       296         1
# 357749      210         0

# %%
data.columns
# Out:
# Index(['id', 'Gender', 'Age', 'Driving_License', 'Region_Code',
#        'Previously_Insured', 'Vehicle_Age', 'Vehicle_Damage', 'Annual_Premium',
#        'Policy_Sales_Channel', 'Vintage', 'Response'],
#       dtype='str')

# %%
# data = data.to_dict(orient="records")

# %%
# DB_NAME = "Proj1"
# COLLECTION_NAME = "Proj1-Data"
# CONNECTION_URL = "mongodb+srv://amitkumarsinghkurmi123_db_user:<put your password>@cluster0.0jsn03m.mongodb.net/?appName=Cluster0"

# %%
# client = pymongo.MongoClient(CONNECTION_URL)
# data_base = client[DB_NAME]
# collection = data_base[COLLECTION_NAME]

# %%
# # Uploading data to MongoDB
# rec = collection.insert_many(data)
